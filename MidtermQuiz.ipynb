# %%
import pandas as pd
#Extract the provided dataset using FLAT FILE

df = pd.read_csv('RT_IOT2022.csv')
df
# Out:
#           no  id.orig_p  id.resp_p proto service  flow_duration  fwd_pkts_tot  \
# 0          0      38667       1883   tcp    mqtt      32.011598             9
# 1          1      51143       1883   tcp    mqtt      31.883584             9
# 2          2      44761       1883   tcp    mqtt      32.124053             9
# 3          3      60893       1883   tcp    mqtt      31.961063             9
# 4          4      51087       1883   tcp    mqtt      31.902362             9
# ...      ...        ...        ...   ...     ...            ...           ...
# 123112  2005      59247      63331   tcp       -       0.000006             1
# 123113  2006      59247      64623   tcp       -       0.000007             1
# 123114  2007      59247      64680   tcp       -       0.000006             1
# 123115  2008      59247      65000   tcp       -       0.000006             1
# 123116  2009      59247      65129   tcp       -       0.000006             1
#
# ...

# %%
phase = pd.DataFrame()

# %%
pip.install kagglehub
import kagglehub

# Download latest version
path = kagglehub.dataset_download("supplejade/rt-iot2022real-time-internet-of-things")

print("Path to dataset files:", path)
# Out:
#   Cell In[45], line 1
#     pip.install kagglehub
#                 ^
# SyntaxError: invalid syntax

# %%
df.dtypes
# Out:
# no                        int64
# id.orig_p                 int64
# id.resp_p                 int64
# proto                    object
# service                  object
#                          ...
# idle.std                float64
# fwd_init_window_size      int64
# bwd_init_window_size      int64
# fwd_last_window_size      int64
# Attack_type              object
# Length: 85, dtype: object

# %%
# What is the lowest min idle time
dfmin = df['idle.min'].min
dfmin
# Out:
# <bound method Series.min of 0         2.972918e+07
# 1         2.985528e+07
# 2         2.984215e+07
# 3         2.991377e+07
# 4         2.981470e+07
#               ...
# 123112    0.000000e+00
# 123113    0.000000e+00
# 123114    0.000000e+00
# 123115    0.000000e+00
# 123116    0.000000e+00
# Name: idle.min, Length: 123117, dtype: float64>

# %%
# What is the largest max idle time
dfmax = df['idle.min'].max
dfmax
# Out:
# <bound method Series.max of 0         2.972918e+07
# 1         2.985528e+07
# 2         2.984215e+07
# 3         2.991377e+07
# 4         2.981470e+07
#               ...
# 123112    0.000000e+00
# 123113    0.000000e+00
# 123114    0.000000e+00
# 123115    0.000000e+00
# 123116    0.000000e+00
# Name: idle.min, Length: 123117, dtype: float64>

# %%
# What is the average idle time
mean = (df['idle.min'] + df['idle.max'])
mean.mean
# Out:
# <bound method Series.mean of 0         5.945837e+07
# 1         5.971055e+07
# 2         5.968430e+07
# 3         5.982755e+07
# 4         5.962941e+07
#               ...
# 123112    0.000000e+00
# 123113    0.000000e+00
# 123114    0.000000e+00
# 123115    0.000000e+00
# 123116    0.000000e+00
# Length: 123117, dtype: float64>

# %%
# What is the average flow duration
flow_ave = df['flow_duration'].mean
flow_ave
# Out:
# <bound method Series.mean of 0         32.011598
# 1         31.883584
# 2         32.124053
# 3         31.961063
# 4         31.902362
#             ...
# 123112     0.000006
# 123113     0.000007
# 123114     0.000006
# 123115     0.000006
# 123116     0.000006
# Name: flow_duration, Length: 123117, dtype: float64>

# %%
df
# Out:
#           no  id.orig_p  id.resp_p proto service  flow_duration  fwd_pkts_tot  \
# 0          0      38667       1883   tcp    mqtt      32.011598             9
# 1          1      51143       1883   tcp    mqtt      31.883584             9
# 2          2      44761       1883   tcp    mqtt      32.124053             9
# 3          3      60893       1883   tcp    mqtt      31.961063             9
# 4          4      51087       1883   tcp    mqtt      31.902362             9
# ...      ...        ...        ...   ...     ...            ...           ...
# 123112  2005      59247      63331   tcp       -       0.000006             1
# 123113  2006      59247      64623   tcp       -       0.000007             1
# 123114  2007      59247      64680   tcp       -       0.000006             1
# 123115  2008      59247      65000   tcp       -       0.000006             1
# 123116  2009      59247      65129   tcp       -       0.000006             1
#
# ...

# %%
df.dtypes
# Out:
# no                        int64
# id.orig_p                 int64
# id.resp_p                 int64
# proto                    object
# service                  object
#                          ...
# idle.std                float64
# fwd_init_window_size      int64
# bwd_init_window_size      int64
# fwd_last_window_size      int64
# Attack_type              object
# Length: 85, dtype: object

# %%
# Get the id 
dfresp = pd.DataFrame(df[['no','id.resp_p','proto','service','flow_duration','Attack_type']])
dfresp
# Out:
#           no  id.resp_p proto service  flow_duration          Attack_type
# 0          0       1883   tcp    mqtt      32.011598         MQTT_Publish
# 1          1       1883   tcp    mqtt      31.883584         MQTT_Publish
# 2          2       1883   tcp    mqtt      32.124053         MQTT_Publish
# 3          3       1883   tcp    mqtt      31.961063         MQTT_Publish
# 4          4       1883   tcp    mqtt      31.902362         MQTT_Publish
# ...      ...        ...   ...     ...            ...                  ...
# 123112  2005      63331   tcp       -       0.000006  NMAP_XMAS_TREE_SCAN
# 123113  2006      64623   tcp       -       0.000007  NMAP_XMAS_TREE_SCAN
# 123114  2007      64680   tcp       -       0.000006  NMAP_XMAS_TREE_SCAN
# 123115  2008      65000   tcp       -       0.000006  NMAP_XMAS_TREE_SCAN
# 123116  2009      65129   tcp       -       0.000006  NMAP_XMAS_TREE_SCAN
#
# [123117 rows x 6 columns]

# %%
head = pd.DataFrame(df.head())
head
# Out:
#    no  id.orig_p  id.resp_p proto service  flow_duration  fwd_pkts_tot  \
# 0   0      38667       1883   tcp    mqtt      32.011598             9
# 1   1      51143       1883   tcp    mqtt      31.883584             9
# 2   2      44761       1883   tcp    mqtt      32.124053             9
# 3   3      60893       1883   tcp    mqtt      31.961063             9
# 4   4      51087       1883   tcp    mqtt      31.902362             9
#
#    bwd_pkts_tot  fwd_data_pkts_tot  bwd_data_pkts_tot  ...  active.std  \
# 0             5                  3                  3  ...         0.0
# 1             5                  3                  3  ...         0.0
# 2             5                  3                  3  ...         0.0
# 3             5                  3                  3  ...         0.0
# 4             5                  3                  3  ...         0.0
#
#        idle.min      idle.max      idle.tot      idle.avg  idle.std  \
# ...

# %%
transformed_csv = dfresp.set_index('no')
transformed_csv
# Out:
#       id.resp_p proto service  flow_duration          Attack_type
# no
# 0          1883   tcp    mqtt      32.011598         MQTT_Publish
# 1          1883   tcp    mqtt      31.883584         MQTT_Publish
# 2          1883   tcp    mqtt      32.124053         MQTT_Publish
# 3          1883   tcp    mqtt      31.961063         MQTT_Publish
# 4          1883   tcp    mqtt      31.902362         MQTT_Publish
# ...         ...   ...     ...            ...                  ...
# 2005      63331   tcp       -       0.000006  NMAP_XMAS_TREE_SCAN
# 2006      64623   tcp       -       0.000007  NMAP_XMAS_TREE_SCAN
# 2007      64680   tcp       -       0.000006  NMAP_XMAS_TREE_SCAN
# 2008      65000   tcp       -       0.000006  NMAP_XMAS_TREE_SCAN
# 2009      65129   tcp       -       0.000006  NMAP_XMAS_TREE_SCAN
#
# [123117 rows x 5 columns]

# %%
 transformed_csv
# Out:
#       id.resp_p proto service  flow_duration          Attack_type
# no
# 0          1883   tcp    mqtt      32.011598         MQTT_Publish
# 1          1883   tcp    mqtt      31.883584         MQTT_Publish
# 2          1883   tcp    mqtt      32.124053         MQTT_Publish
# 3          1883   tcp    mqtt      31.961063         MQTT_Publish
# 4          1883   tcp    mqtt      31.902362         MQTT_Publish
# ...         ...   ...     ...            ...                  ...
# 2005      63331   tcp       -       0.000006  NMAP_XMAS_TREE_SCAN
# 2006      64623   tcp       -       0.000007  NMAP_XMAS_TREE_SCAN
# 2007      64680   tcp       -       0.000006  NMAP_XMAS_TREE_SCAN
# 2008      65000   tcp       -       0.000006  NMAP_XMAS_TREE_SCAN
# 2009      65129   tcp       -       0.000006  NMAP_XMAS_TREE_SCAN
#
# [123117 rows x 5 columns]
